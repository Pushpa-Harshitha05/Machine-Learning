# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpa-Harshitha05/Machine-Learning/blob/main/Gathering_data(csv%20and%20pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Gathering data</h1>
#
# <h4>CSV Files</h4>
# <h4>JSON/SQL</h4>
# <h4>Fetch from API</h4>
# <h4>Fetch data using web scraping</h4>

# %% [markdown]
# .

# %%
import pandas as pd

# the url should be raw data form of csv file.
url = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Air%20Quality/real_2016_air.csv"

df = pd.read_csv(url)
df
# Out:
#         T    TM    Tm     SLP   H   VV     V    VM      PM 2.5
# 0    16.9  25.1   6.6  1021.3  65  1.1   2.0   7.6  284.795833
# 1    15.5  24.1   7.7  1021.0  71  1.1   3.5  11.1  219.720833
# 2    14.9  22.8   8.0  1018.4  73  1.1   5.9  13.0  182.187500
# 3    18.3  24.7  11.5  1018.1  85  0.5   1.1   7.6  154.037500
# 4    16.5  24.7  12.0  1017.4  82  0.6   8.0  13.0  223.208333
# ..    ...   ...   ...     ...  ..  ...   ...   ...         ...
# 176  18.1  24.0  11.2  1015.4  56  1.8  15.9  25.9  288.416667
# 177  17.8  25.0  10.7  1015.8  54  2.3   9.4  22.2  256.833333
# 178  13.9  24.5  11.4  1015.0  95  0.6   8.7  14.8  169.000000
# 179  16.3  23.0   9.8  1016.9  78  1.1   7.4  16.5  186.041667
# 180  16.3  23.4   9.0  1017.3  68  1.3   7.8  18.3  185.583333
#
# [181 rows x 9 columns]

# %% [markdown]
# <H1>For tab seperated values (tsv) files, use seperator<br>data = pd.read_csv('file name',sep='\t')</H1><hr>

# %% [markdown]
# .

# %% [markdown]
# If column names are not given:
# df = pd.read_csv("file",names=['a','b',...])  <br>names will be the column names<hr>

# %% [markdown]
# If column names are given but they are given as first row of data, the we will use header<br> df = pd.read_csv("file",header=1)<br>  the first row will be set as col names<hr>

# %% [markdown]
# if we want only some cols<br>
# pd.read_csv("file", usecols = ['col1','col2',..])

# %%
data = pd.read_csv('https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Air%20Quality/real_2016_air.csv',on_bad_lines='skip')  # skips rows with bad values. example: if the dataset has 8 cols and a row have less than 8 or more than 8 values, those rows will be skipped.
data
# Out:
#         T    TM    Tm     SLP   H   VV     V    VM      PM 2.5
# 0    16.9  25.1   6.6  1021.3  65  1.1   2.0   7.6  284.795833
# 1    15.5  24.1   7.7  1021.0  71  1.1   3.5  11.1  219.720833
# 2    14.9  22.8   8.0  1018.4  73  1.1   5.9  13.0  182.187500
# 3    18.3  24.7  11.5  1018.1  85  0.5   1.1   7.6  154.037500
# 4    16.5  24.7  12.0  1017.4  82  0.6   8.0  13.0  223.208333
# ..    ...   ...   ...     ...  ..  ...   ...   ...         ...
# 176  18.1  24.0  11.2  1015.4  56  1.8  15.9  25.9  288.416667
# 177  17.8  25.0  10.7  1015.8  54  2.3   9.4  22.2  256.833333
# 178  13.9  24.5  11.4  1015.0  95  0.6   8.7  14.8  169.000000
# 179  16.3  23.0   9.8  1016.9  78  1.1   7.4  16.5  186.041667
# 180  16.3  23.4   9.0  1017.3  68  1.3   7.8  18.3  185.583333
#
# [181 rows x 9 columns]

# %%
# astype - change datatype of a column

data["T"] = data['T'].astype(int)
data
# Out:
#       T    TM    Tm     SLP   H   VV     V    VM      PM 2.5
# 0    16  25.1   6.6  1021.3  65  1.1   2.0   7.6  284.795833
# 1    15  24.1   7.7  1021.0  71  1.1   3.5  11.1  219.720833
# 2    14  22.8   8.0  1018.4  73  1.1   5.9  13.0  182.187500
# 3    18  24.7  11.5  1018.1  85  0.5   1.1   7.6  154.037500
# 4    16  24.7  12.0  1017.4  82  0.6   8.0  13.0  223.208333
# ..   ..   ...   ...     ...  ..  ...   ...   ...         ...
# 176  18  24.0  11.2  1015.4  56  1.8  15.9  25.9  288.416667
# 177  17  25.0  10.7  1015.8  54  2.3   9.4  22.2  256.833333
# 178  13  24.5  11.4  1015.0  95  0.6   8.7  14.8  169.000000
# 179  16  23.0   9.8  1016.9  78  1.1   7.4  16.5  186.041667
# 180  16  23.4   9.0  1017.3  68  1.3   7.8  18.3  185.583333
#
# [181 rows x 9 columns]

# %% [markdown]
# <h1>Converters</h1><h3>used to change value of a col</h3>

# %%
def rename(text):
  text = float(text)
  if text == 1021.3:
    return 0
  else:
    return 1

# %%
pd.read_csv('https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Air%20Quality/real_2016_air.csv',converters={'SLP':rename})
# Out:
#         T    TM    Tm  SLP   H   VV     V    VM      PM 2.5
# 0    16.9  25.1   6.6    0  65  1.1   2.0   7.6  284.795833
# 1    15.5  24.1   7.7    1  71  1.1   3.5  11.1  219.720833
# 2    14.9  22.8   8.0    1  73  1.1   5.9  13.0  182.187500
# 3    18.3  24.7  11.5    1  85  0.5   1.1   7.6  154.037500
# 4    16.5  24.7  12.0    1  82  0.6   8.0  13.0  223.208333
# ..    ...   ...   ...  ...  ..  ...   ...   ...         ...
# 176  18.1  24.0  11.2    1  56  1.8  15.9  25.9  288.416667
# 177  17.8  25.0  10.7    1  54  2.3   9.4  22.2  256.833333
# 178  13.9  24.5  11.4    1  95  0.6   8.7  14.8  169.000000
# 179  16.3  23.0   9.8    1  78  1.1   7.4  16.5  186.041667
# 180  16.3  23.4   9.0    1  68  1.3   7.8  18.3  185.583333
#
# [181 rows x 9 columns]

# %% [markdown]
# <h1>Loading a huge dataset in chunks using chunksize=</h1>

# %%
data = pd.read_csv('https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Air%20Quality/real_2016_air.csv',chunksize=100)

for chunks in data:
  print(chunks.shape)
# Out:
# (100, 9)
# (81, 9)

# %% [markdown]
# <br><br><hr><h1>Understanding your data</h1>

# %% [markdown]
# <h3>
# understanding your data (7 Questions you ask to your data)<br>
#     <h4>
#     1. How big is the data? - df.shape<br>
#     2. How does the data look like? -  df.head() and df.sample()<br>
#     3. What is the data type of each columns? - df.info()<br>
#     4. Are there any missing values? - df.isnull().sum()<br>
#     5. How does the data look mathematically? - df.describe()<br>
#     6. Are there duplicate values? - df.duplicated().sum()<br>
#     7. How is the correlation between the columns? - df.corr()<br>
#     </h4>
# </h3>
